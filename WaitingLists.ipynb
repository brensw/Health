# %% [markdown]
# <a href="https://colab.research.google.com/github/brensw/Health/blob/main/WaitingLists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as numpy
import matplotlib as plt



from google.colab import files


uploaded = files.upload()

print(uploaded)
# Out:
#      <input type="file" id="files-8d9f1e76-692b-4c34-ad30-b8cffad3141e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d9f1e76-692b-4c34-ad30-b8cffad3141e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IPDC Waiting List By Group Hospital 2021.csv to IPDC Waiting List By Group Hospital 2021.csv
# ...

# %%
print(uploaded)

# %%
#from datetime import datetime
#d_parser= lambda x : datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv ('IPDC Waiting List By Group Hospital 2021.csv')
df.head(50)
# Out:
#    Archive_Date             Hospital_Group  ...     Time_Bands Total
# 0    28/01/2021  Children's Health Ireland  ...     3-6 Months     2
# 1    28/01/2021  Children's Health Ireland  ...    9-12 Months     1
# 2    28/01/2021  Children's Health Ireland  ...     18+ Months     1
# 3    28/01/2021  Children's Health Ireland  ...     6-9 Months     1
# 4    28/01/2021  Children's Health Ireland  ...     0-3 Months     3
# 5    28/01/2021  Children's Health Ireland  ...    9-12 Months     1
# 6    28/01/2021  Children's Health Ireland  ...   12-15 Months     2
# 7    28/01/2021  Children's Health Ireland  ...   15-18 Months     1
# 8    28/01/2021  Children's Health Ireland  ...     18+ Months     1
# 9    28/01/2021  Children's Health Ireland  ...   12-15 Months     1
# 10   28/01/2021  Children's Health Ireland  ...     0-3 Months   144
# 11   28/01/2021  Children's Health Ireland  ...     3-6 Months    66
# 12   28/01/2021  Children's Health Ireland  ...     6-9 Months     8
# ...

# %%
df['Archive_Date']= pd.to_datetime(df['Archive_Date'], format= '%d/%m/%Y')

# %%
df.loc[0,'Archive_Date'].day_name()
#df['Archive_Date'].dt.day_name()
# Out:
# 'Thursday'

# %%
 df['Archive_Date'].dt.day_name()
# Out:
# 0        Thursday
# 1        Thursday
# 2        Thursday
# 3        Thursday
# 4        Thursday
#            ...
# 15882    Thursday
# 15883    Thursday
# 15884    Thursday
# 15885    Thursday
# 15886    Thursday
# Name: Archive_Date, Length: 15887, dtype: object

# %%
df.set_index('Archive_Date', inplace=True)

# %%
df.head()
# Out:
#                          Hospital_Group  Hospital_HIPE  ...     Time_Bands  Total
# Archive_Date                                            ...
# 28/01/2021    Children's Health Ireland              0  ...     3-6 Months      2
# 28/01/2021    Children's Health Ireland              0  ...    9-12 Months      1
# 28/01/2021    Children's Health Ireland              0  ...     18+ Months      1
# 28/01/2021    Children's Health Ireland              0  ...     6-9 Months      1
# 28/01/2021    Children's Health Ireland              0  ...     0-3 Months      3
#
# [5 rows x 10 columns]

# %%
df['2021']['Total'].sum()
# Out:
# 242365

# %%
Monthly_Total= df['Total'].resample('M').sum()

# %%
Monthly_Total[ '03/2021']
# Out:
# Archive_Date
# 2021-03-31    79973
# Freq: M, Name: Total, dtype: int64

# %%
# %matplotlib inline

# %%
Monthly_Total.plot()

# %%
waiting= df.groupby('Hospital_Group').sum()

waiting.head()
# Out:
#                                      Hospital_HIPE  Specialty_HIPE  Total
# Hospital_Group
# Children's Health Ireland                        0         3495888  17525
# Dublin Midlands Hospital Group             1936552         6185151  35768
# Ireland East Hospital Group                2327454         8190809  52214
# RCSI  Hospitals Group                      1060434         4640597  24798
# Saolta University Health Care Group        2264014         9541697  54339

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
waiting['Hospital_Group'] = waiting.index

# %%
sns.set_theme(style="whitegrid")

sns.set_color_codes("pastel")
sns.barplot(x="Total", y="Hospital_Group", data= waiting)
